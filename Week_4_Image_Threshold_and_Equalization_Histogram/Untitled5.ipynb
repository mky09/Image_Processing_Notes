# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img_gray=cv2.imread("./The-cameraman-picture-with-256-256-size.png",0)
histr= cv2.calcHist([img_gray],[0],None,[256],[0,256])
plt.plot(histr)
plt.show()

# %%
img_gray= cv2.imread("./The-cameraman-picture-with-256-256-size.png",0)
img_eq_hist = cv2.equalizeHist(img_gray)

fig=plt.figure(figsize=(10,7))
rows = 1
columns = 2
fig.add_subplot(rows, columns,1)
plt.imshow(my_img_gray,cmap="gray")
plt.axis("off")
plt.title("original İmage")
fig.add_subplot(rows,columns,2)
plt.imshow(my_tresh_binary,cmap="gray")
plt.axis("off")
plt.title("binary")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 8
#       6 columns = 2
#       7 fig.add_subplot(rows, columns,1)
# ----> 8 plt.imshow(my_img_gray,cmap="gray")
#       9 plt.axis("off")
#      10 plt.title("original İmage")
#
# NameError: name 'my_img_gray' is not defined

# %%
hist_ogr= cv2.calcHist([img_gray],[0],None,[256],[0,256])
hist_eq= cv2.calcHist([img_eq_hist],[0],None,[256],[0,256])

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(hist_ogr,color="b")
plt.title("orginal dmsa")

plt.subplot(1,2,2)
plt.plot(hist_ogr,color="b")
plt.title("orginal sonrası hs")
plt.plot(histr)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 2
#       1 hist_ogr= cv2.calcHist([img_gray],[0],None,[256],[0,256])
# ----> 2 hist_eq= cv2.calcHist([img_eq_hist],[0],None,[256],[0,256])
#       4 plt.figure(figsize=(12,5))
#       5 plt.subplot(1,2,1)
#
# NameError: name 'img_eq_hist' is not defined

# %%
import cv2
import matplotlib.pyplot as plt


hist_ogr = cv2.calcHist([img_gray], [0], None, [256], [0, 256])
hist_eq = cv2.calcHist([img_eq_hist], [0], None, [256], [0, 256])  # Virgül eklendi


plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(hist_ogr, color="b")
plt.title("Orijinal Görüntü Histogramı")

plt.subplot(1, 2, 2)
plt.plot(hist_eq, color="r")  
plt.title("Histogram Eşitleme Sonrası")

plt.tight_layout()
plt.show()
